# %% [markdown]
# <h1 style="text-align: center;" class="list-group-item list-group-item-action active">Table of Contents</h1>
#
# <ul style="list-style-type:none;">
#          <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2" role="tab"
#                         aria-controls="settings">2. Exploratory Data Analysis <span
#                             class="badge badge-primary badge-pill">4</span></a>
#          </li>
#             <ul
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.1"role="tab"
#                         aria-controls="settings">2.1. Shape of the DataFrame <span
#                             class="badge badge-primary badge-pill">5</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.2"role="tab"
#                         aria-controls="settings">2.2. Information about the DataFrame <span
#                             class="badge badge-primary badge-pill">6</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.3" role="tab"
#                         aria-controls="settings">2.3. Describing the DataFrame <span
#                             class="badge badge-primary badge-pill">7</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.4" role="tab"
#                         aria-controls="settings">2.4. Visualization of Age Distribution <span
#                             class="badge badge-primary badge-pill">8</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.5" role="tab"
#                         aria-controls="settings">2.5. Visualization of Probability Distribution of Age <span
#                             class="badge badge-primary badge-pill">9</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.6" role="tab"
#                         aria-controls="settings">2.6. Visualization of Features: Group and SES <span
#                             class="badge badge-primary badge-pill">10</span></a></li>
#                <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.7" role="tab"
#                         aria-controls="settings">2.7. Visualization of Features: Clinical Dementia Rating (CDR) and Group <span
#                             class="badge badge-primary badge-pill">8</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.5" role="tab"
#                     aria-controls="settings">2.8.  Visualization of Features: Min-Mental State Exam (MMSE), Age and Group <span
#                             class="badge badge-primary badge-pill">9</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#2.6" role="tab"
#                      aria-controls="settings">2.9. Visualization of Features: Estimated Intracranial Volume (eTIV), Age
#                      and Gender <span class="badge badge-primary badge-pill">10</span></a></li>
#             </ul>
#           <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3" role="tab"
#                         aria-controls="settings">3. Feature Engineering <span
#                             class="badge badge-primary badge-pill">11</span></a>
#          </li>
#          <ul
#              <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.1" role="tab"
#                         aria-controls="settings">3.1. Missing Values Before <span
#                             class="badge badge-primary badge-pill">12</span></a></li>
#              <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.2" role="tab"
#                         aria-controls="settings">3.2. Filling Missing Values  <span
#                             class="badge badge-primary badge-pill">13</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.3"role="tab"
#                      aria-controls="settings">3.3. Missing Values After <span
#                                     class="badge badge-primary badge-pill">14</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.4" role="tab"
#                      aria-controls="settings">3.4. Rename Column M/F to Gender <span
#                                     class="badge badge-primary badge-pill">15</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.5" role="tab"
#                      aria-controls="settings">3.5. Make Dummies of Gender <span
#                                     class="badge badge-primary badge-pill">16</span></a></li>
#               <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#3.6" role="tab"
#                      aria-controls="settings">3.6. Heatmap of Features<span
#                                     class="badge badge-primary badge-pill">17</span></a></li>

# %% [markdown]
# <h1 style="text-align: center;" class="list-group-item list-group-item-action active">Table of Contents</h1>
# <ul style="list-style-type:none;">
#     <li><a class="list-group-item list-group-item-action"> * [Business Problem Understanding](#1)?</a></li>
#     * [Problem Statement](#2)
#
#     * [Hypothesis](#3)
#     * [Project Goal](#4)
#     * [The Dataset](#5)
# * [Data Preparation](#6)
#     * [Data Quality Assessment](#7)
#     * [Data Cleaning and Preprocessing](#8)
# * [Exploratory Data Analysis](#9)
# * [Statistical Analysis](#10)
#     * [Removing Outliers](#ro)
#     * [Normality Test](#nt)
#     * [Box-Cos Transformation](#bct)
#     * [Welch's t-Test](#wt)
#     * [Effect Size](#es)
#     * [Confidence Interval](#ci)
# * [Feature Engineering and Selection](#fes)
# * [Data Modeling](#dm)
#     * [Data Understanding](#du)
#         * [Descriptive Statistics](#ds)
#         * [Data Visualization](#dv)
#     * [Splitting Dataset](#sd)
#     * [Algorithm Evaluation](#ae)
#     * [Parameter Tuning](#pt)
#     * [Final Model](#fm)
#     * [Model Understanding](#mu)
#     * [Save Model](#sm)
# * [Conclusion and Recommendation](#cr)
# * [References](#r)
#     </ul>
